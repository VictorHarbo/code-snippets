# %%
import pandas as pd
import matplotlib.pyplot as plt

# Import dataframe
df = pd.read_csv(r'../data/poverty_ourWorldInData.csv')

# Filter data
denmark = df[df['country'] == "Denmark"]


# Creating bar plot from columns
denmark.plot(x="year", y="gini", kind="bar", 
             xlabel="År", ylabel="Gini koficient", 
             title="Gini koficient i Danmark")
# Out:
# <AxesSubplot:title={'center':'Gini koficient i Danmark'}, xlabel='År', ylabel='Gini koficient'>
